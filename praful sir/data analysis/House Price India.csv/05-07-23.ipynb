# %%
# Import the packages
import numpy as np
import pandas as pd

# %%
# load the dataset
House_Price_Dataset = pd.read_csv("House Price India.csv")

# %%
# Task 1: Show the first 10 Records
House_Price_Dataset.head(10)
# Out:
#            id   Date  number of bedrooms  number of bathrooms  living area  \
# 0  6762810145  42491                   5                 2.50         3650
# 1  6762810635  42491                   4                 2.50         2920
# 2  6762810998  42491                   5                 2.75         2910
# 3  6762812605  42491                   4                 2.50         3310
# 4  6762812919  42491                   3                 2.00         2710
# 5  6762813105  42491                   3                 2.50         2600
# 6  6762813157  42491                   5                 3.25         3660
# 7  6762813599  42491                   3                 1.75         2240
# 8  6762813600  42491                   3                 2.50         2390
# 9  6762814461  42491                   4                 2.25         2200
#
#    lot area  number of floors  waterfront present  number of views  \
# 0      9050               2.0                   0                4
# ...

# %%
# Task 2: Show the last 10 Records
House_Price_Dataset.tail(10)
# Out:
#                id   Date  number of bedrooms  number of bathrooms  \
# 14610  6762828349  42734                   4                 2.75
# 14611  6762828783  42734                   3                 1.75
# 14612  6762828856  42734                   3                 1.00
# 14613  6762829600  42734                   3                 1.00
# 14614  6762829669  42734                   3                 1.75
# 14615  6762830250  42734                   2                 1.50
# 14616  6762830339  42734                   3                 2.00
# 14617  6762830618  42734                   2                 1.00
# 14618  6762830709  42734                   4                 1.00
# 14619  6762831463  42734                   3                 1.00
#
#        living area  lot area  number of floors  waterfront present  \
# 14610         1810      7350               1.0                   0
# 14611         1350      7686               1.0                   0
# ...

# %%
# Task 3: Show the size of the Data
House_Price_Dataset.shape

# We have 14620 Observations
# We have 23 attributes
# Out:
# (14620, 23)

# %% [markdown]
# # #Steps to Get Inferance from the data or EDA (Exploratory Data Analysis)

# %% [markdown]
# # #Step1 :- Data Pre-Processing

# %% [markdown]
# # #Step 2 :- EDA

# %% [markdown]
# # #Step 3 :- Draw The Conclusion

# %%
House_Price_Dataset.head()
# Out:
#            id   Date  number of bedrooms  number of bathrooms  living area  \
# 0  6762810145  42491                   5                 2.50         3650
# 1  6762810635  42491                   4                 2.50         2920
# 2  6762810998  42491                   5                 2.75         2910
# 3  6762812605  42491                   4                 2.50         3310
# 4  6762812919  42491                   3                 2.00         2710
#
#    lot area  number of floors  waterfront present  number of views  \
# 0      9050               2.0                   0                4
# 1      4000               1.5                   0                0
# 2      9480               1.5                   0                0
# 3     42998               2.0                   0                0
# 4      4500               1.5                   0                0
#
#    condition of the house  ...  Built Year  Renovation Year  Postal Code  \
# ...

# %%
# List out all the column Names
House_Price_Dataset.columns
# Out:
# Index(['id', 'Date', 'number of bedrooms', 'number of bathrooms',
#        'living area', 'lot area', 'number of floors', 'waterfront present',
#        'number of views', 'condition of the house', 'grade of the house',
#        'Area of the house(excluding basement)', 'Area of the basement',
#        'Built Year', 'Renovation Year', 'Postal Code', 'Lattitude',
#        'Longitude', 'living_area_renov', 'lot_area_renov',
#        'Number of schools nearby', 'Distance from the airport', 'Price'],
#       dtype='object')

# %%
# Check for valid Null Values in Data Set
House_Price_Dataset.isnull().sum()
# Out:
# id                                       0
# Date                                     0
# number of bedrooms                       0
# number of bathrooms                      0
# living area                              0
# lot area                                 0
# number of floors                         0
# waterfront present                       0
# number of views                          0
# condition of the house                   0
# grade of the house                       0
# Area of the house(excluding basement)    0
# Area of the basement                     0
# Built Year                               0
# Renovation Year                          0
# Postal Code                              0
# Lattitude                                0
# Longitude                                0
# living_area_renov                        0
# lot_area_renov                           0
# Number of schools nearby                 0
# Distance from the airport                0
# ...

# %% [markdown]
# Inference
#
# We don't have any valid null vlaues in the data

# %% [markdown]
# Access the set of columns.

# %%
House_Price_Dataset.columns
# Out:
# Index(['id', 'Date', 'number of bedrooms', 'number of bathrooms',
#        'living area', 'lot area', 'number of floors', 'waterfront present',
#        'number of views', 'condition of the house', 'grade of the house',
#        'Area of the house(excluding basement)', 'Area of the basement',
#        'Built Year', 'Renovation Year', 'Postal Code', 'Lattitude',
#        'Longitude', 'living_area_renov', 'lot_area_renov',
#        'Number of schools nearby', 'Distance from the airport', 'Price'],
#       dtype='object')

# %%
House_Price_Dataset_Home_Coordinats=House_Price_Dataset[[
    'number of bedrooms',
    'number of bathrooms',
    'living area',
    'lot area',
    'number of floors',
    'condition of the house',
    'Area of the house(excluding basement)',
    'Area of the basement'
]]

House_Price_Dataset_Home_Coordinats
# Out:
#        number of bedrooms  number of bathrooms  living area  lot area  \
# 0                       5                 2.50         3650      9050
# 1                       4                 2.50         2920      4000
# 2                       5                 2.75         2910      9480
# 3                       4                 2.50         3310     42998
# 4                       3                 2.00         2710      4500
# ...                   ...                  ...          ...       ...
# 14615                   2                 1.50         1556     20000
# 14616                   3                 2.00         1680      7000
# 14617                   2                 1.00         1070      6120
# 14618                   4                 1.00         1030      6621
# 14619                   3                 1.00          900      4770
#
#        number of floors  condition of the house  \
# 0                   2.0                       5
# ...

# %%
# Access the Area Coordinats
House_Price_Dataset.columns
# Out:
# Index(['id', 'Date', 'number of bedrooms', 'number of bathrooms',
#        'living area', 'lot area', 'number of floors', 'waterfront present',
#        'number of views', 'condition of the house', 'grade of the house',
#        'Area of the house(excluding basement)', 'Area of the basement',
#        'Built Year', 'Renovation Year', 'Postal Code', 'Lattitude',
#        'Longitude', 'living_area_renov', 'lot_area_renov',
#        'Number of schools nearby', 'Distance from the airport', 'Price'],
#       dtype='object')

# %%
# Access the Area Coordinats
House_Price_Dataset_Area_Coordinats=House_Price_Dataset[[
    'waterfront present',
    'Postal Code',
    'Lattitude',
    'Longitude',
    'Number of schools nearby',
    'Distance from the airport'
]]

House_Price_Dataset_Area_Coordinats
# Out:
#        waterfront present  Postal Code  Lattitude  Longitude  \
# 0                       0       122003    52.8645   -114.557
# 1                       0       122004    52.8878   -114.470
# 2                       0       122004    52.8852   -114.468
# 3                       0       122005    52.9532   -114.321
# 4                       0       122006    52.9047   -114.485
# ...                   ...          ...        ...        ...
# 14615                   0       122066    52.6191   -114.472
# 14616                   0       122072    52.5075   -114.393
# 14617                   0       122056    52.7289   -114.507
# 14618                   0       122042    52.7157   -114.411
# 14619                   0       122018    52.5338   -114.552
#
#        Number of schools nearby  Distance from the airport
# 0                             2                         58
# 1                             2                         51
# ...

# %%
# Access the Renovation Coordinats
House_Price_Dataset.columns
# Out:
# Index(['id', 'Date', 'number of bedrooms', 'number of bathrooms',
#        'living area', 'lot area', 'number of floors', 'waterfront present',
#        'number of views', 'condition of the house', 'grade of the house',
#        'Area of the house(excluding basement)', 'Area of the basement',
#        'Built Year', 'Renovation Year', 'Postal Code', 'Lattitude',
#        'Longitude', 'living_area_renov', 'lot_area_renov',
#        'Number of schools nearby', 'Distance from the airport', 'Price'],
#       dtype='object')

# %%
# Access the Area Coordinats
House_Price_Dataset_Renovation_Coordinats=House_Price_Dataset[[
    'Renovation Year',
    'living_area_renov',
    'lot_area_renov'
]]

House_Price_Dataset_Renovation_Coordinats
# Out:
#        Renovation Year  living_area_renov  lot_area_renov
# 0                    0               2880            5400
# 1                    0               2470            4000
# 2                    0               2940            6600
# 3                    0               3350           42847
# 4                    0               2060            4500
# ...                ...                ...             ...
# 14615                0               2250           17286
# 14616                0               1540            7480
# 14617                0               1130            6120
# 14618                0               1420            6631
# 14619             2009                900            3480
#
# [14620 rows x 3 columns]

# %%
# Access the Renovation Coordinats
House_Price_Dataset.columns
# Out:
# Index(['id', 'Date', 'number of bedrooms', 'number of bathrooms',
#        'living area', 'lot area', 'number of floors', 'waterfront present',
#        'number of views', 'condition of the house', 'grade of the house',
#        'Area of the house(excluding basement)', 'Area of the basement',
#        'Built Year', 'Renovation Year', 'Postal Code', 'Lattitude',
#        'Longitude', 'living_area_renov', 'lot_area_renov',
#        'Number of schools nearby', 'Distance from the airport', 'Price'],
#       dtype='object')

# %%
House_Price_Dataset_Establishment_Coordinats=House_Price_Dataset[[
    'id',
    'Date',
    'number of views',
    'condition of the house',
    'grade of the house',
    'Price',
    'Built Year'
]]

House_Price_Dataset_Establishment_Coordinats
# Out:
#                id   Date  number of views  condition of the house  \
# 0      6762810145  42491                4                       5
# 1      6762810635  42491                0                       5
# 2      6762810998  42491                0                       3
# 3      6762812605  42491                0                       3
# 4      6762812919  42491                0                       4
# ...           ...    ...              ...                     ...
# 14615  6762830250  42734                0                       4
# 14616  6762830339  42734                0                       4
# 14617  6762830618  42734                0                       3
# 14618  6762830709  42734                0                       4
# 14619  6762831463  42734                0                       3
#
#        grade of the house    Price  Built Year
# 0                      10  2380000        1921
# 1                       8  1400000        1909
# ...

# %% [markdown]
# Univariate Analysis to Authanticate the Data
# A. Home Cordinates

# %%
House_Price_Dataset_Home_Coordinats.head(3)
# Out:
#    number of bedrooms  number of bathrooms  living area  lot area  \
# 0                   5                 2.50         3650      9050
# 1                   4                 2.50         2920      4000
# 2                   5                 2.75         2910      9480
#
#    number of floors  condition of the house  \
# 0               2.0                       5
# 1               1.5                       5
# 2               1.5                       3
#
#    Area of the house(excluding basement)  Area of the basement
# 0                                   3370                   280
# 1                                   1910                  1010
# 2                                   2910                     0

# %%
House_Price_Dataset_Home_Coordinats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14620 entries, 0 to 14619
# Data columns (total 8 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   number of bedrooms                     14620 non-null  int64
#  1   number of bathrooms                    14620 non-null  float64
#  2   living area                            14620 non-null  int64
#  3   lot area                               14620 non-null  int64
#  4   number of floors                       14620 non-null  float64
#  5   condition of the house                 14620 non-null  int64
#  6   Area of the house(excluding basement)  14620 non-null  int64
#  7   Area of the basement                   14620 non-null  int64
# dtypes: float64(2), int64(6)
# memory usage: 913.9 KB

# %% [markdown]
# Inference
#
# In this home coordinate dataset we have all Columns Numirical in Nature.
# In the same 2 columns as Float and remaining 6 are interger

# %%
House_Price_Dataset_Home_Coordinats.describe().T
# Out:
#                                          count          mean           std  \
# number of bedrooms                     14620.0      3.379343      0.938719
# number of bathrooms                    14620.0      2.129583      0.769934
# living area                            14620.0   2098.262996    928.275721
# lot area                               14620.0  15093.281122  37919.621304
# number of floors                       14620.0      1.502360      0.540239
# condition of the house                 14620.0      3.430506      0.664151
# Area of the house(excluding basement)  14620.0   1801.783926    833.809963
# Area of the basement                   14620.0    296.479070    448.551409
#
#                                          min      25%      50%      75%  \
# number of bedrooms                       1.0     3.00     3.00      4.0
# number of bathrooms                      0.5     1.75     2.25      2.5
# living area                            370.0  1440.00  1930.00   2570.0
# ...

# %%
#now the time is to visualise the exisxting home coordinate

#import seaborn library

import seaborn as sns
#import Matplotlib
import matplotlib.pyplot as plt

# %%
#draw the pairplot

sns.pairplot(House_Price_Dataset_Home_Coordinats)
plt.show()
